# %%
pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ultralytics==8.0.196
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="6DrCMZbuvrOUq8OrfTvw")
project = rf.workspace("mltask").project("mltask")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# Setup complete ✅ (44 CPUs, 125.8 GB RAM, 146.9/599.0 GB disk)

# %%
# !yolo train model=yolov8n.pt data="data.yaml" epochs=50 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.17 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# ...

# %%
# !yolo track source="track_this.mp4" save=True model="/workspace/Jupyter/datasets/MLTask-1/runs/detect/train6/weights/best.pt"
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.10 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3090, 24260MiB)
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 (no detections), 103.8ms
# video 1/1 (2/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Mouse, 8.5ms
# video 1/1 (3/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Keyboard, 1 Mouse, 8.0ms
# video 1/1 (4/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Keyboard, 1 Monitor, 1 Mouse, 8.1ms
# video 1/1 (5/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Monitor, 1 Mouse, 7.6ms
# video 1/1 (6/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Monitor, 1 Mouse, 13.1ms
# video 1/1 (7/211) /workspace/Jupyter/datasets/MLTask-1/track_this.mp4: 384x640 1 Monitor, 1 Mouse, 9.8ms
# ...

# %%
pip install lap
# Out:
# ...
#      |████████████████████████████████| 1.5 MB 1.2 MB/s eta 0:00:01
# ...
#   Created wheel for lap: filename=lap-0.4.0-cp38-cp38-linux_x86_64.whl size=1679713 sha256=f46fc91f8687dc0907575471a6348a8be007ddda4fee7910cfbe413c159f912a
#   Stored in directory: /root/.cache/pip/wheels/86/ec/8a/2baa6fb3ea3a3bdc40a9c2c4b8957b5b544f207531f7a78a89
# Successfully built lap
# ...
# Note: you may need to restart the kernel to use updated packages.
